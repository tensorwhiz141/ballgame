# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('../data/emg_sensor3.csv')

# %%
df
# Out:
#       ch1_voltage  ch2_voltage  ch3_voltage  label
# 0            0.51         0.79         0.64      1
# 1            0.51         0.62         0.55      1
# 2            0.47         0.12         0.49      1
# 3            0.19         0.50         0.78      1
# 4            0.90         0.67         0.74      1
# ...           ...          ...          ...    ...
# 1995         1.02         1.28         0.47      2
# 1996         0.30         0.79         0.60      2
# 1997         0.42         0.71         0.43      2
# 1998         0.88         0.11         0.77      2
# 1999         1.64         0.94         0.21      2
#
# [2000 rows x 4 columns]

# %%
df.head(5)
# Out:
#    ch1_voltage  ch2_voltage  ch3_voltage  label
# 0         0.51         0.79         0.64      1
# 1         0.51         0.62         0.55      1
# 2         0.47         0.12         0.49      1
# 3         0.19         0.50         0.78      1
# 4         0.90         0.67         0.74      1

# %%
df.dropna()
# Out:
#       ch1_voltage  ch2_voltage  ch3_voltage  label
# 0            0.51         0.79         0.64      1
# 1            0.51         0.62         0.55      1
# 2            0.47         0.12         0.49      1
# 3            0.19         0.50         0.78      1
# 4            0.90         0.67         0.74      1
# ...           ...          ...          ...    ...
# 1995         1.02         1.28         0.47      2
# 1996         0.30         0.79         0.60      2
# 1997         0.42         0.71         0.43      2
# 1998         0.88         0.11         0.77      2
# 1999         1.64         0.94         0.21      2
#
# [2000 rows x 4 columns]

# %%
df
# Out:
#       ch1_voltage  ch2_voltage  ch3_voltage  label
# 0            0.51         0.79         0.64      1
# 1            0.51         0.62         0.55      1
# 2            0.47         0.12         0.49      1
# 3            0.19         0.50         0.78      1
# 4            0.90         0.67         0.74      1
# ...           ...          ...          ...    ...
# 1995         1.02         1.28         0.47      2
# 1996         0.30         0.79         0.60      2
# 1997         0.42         0.71         0.43      2
# 1998         0.88         0.11         0.77      2
# 1999         1.64         0.94         0.21      2
#
# [2000 rows x 4 columns]

# %%
x=df.drop(columns=['label'],axis='columns')

# %%
x
# Out:
#       ch1_voltage  ch2_voltage  ch3_voltage
# 0            0.51         0.79         0.64
# 1            0.51         0.62         0.55
# 2            0.47         0.12         0.49
# 3            0.19         0.50         0.78
# 4            0.90         0.67         0.74
# ...           ...          ...          ...
# 1995         1.02         1.28         0.47
# 1996         0.30         0.79         0.60
# 1997         0.42         0.71         0.43
# 1998         0.88         0.11         0.77
# 1999         1.64         0.94         0.21
#
# [2000 rows x 3 columns]

# %%
y=df['label']

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1995    2
# 1996    2
# 1997    2
# 1998    2
# 1999    2
# Name: label, Length: 2000, dtype: int64

# %%
scaler=StandardScaler()

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
X_train
# Out:
#       ch1_voltage  ch2_voltage  ch3_voltage
# 968          0.14         0.36         0.60
# 240          0.71         0.16         0.14
# 819          0.97         0.58         0.32
# 692          1.06         0.76         0.66
# 420          0.22         0.17         0.51
# ...           ...          ...          ...
# 1130         0.29         0.28         0.45
# 1294         0.13         0.68         0.37
# 860          0.24         0.17         0.74
# 1459         1.01         0.84         1.25
# 1126         0.50         0.25         0.28
#
# [1600 rows x 3 columns]

# %%
model=DecisionTreeClassifier(criterion='entropy',max_depth=10000, min_samples_leaf=100,class_weight='balanced',random_state=70)

# %%
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=10000, min_samples_leaf=100, random_state=70)

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score,accuracy_score

# %%
mae = mean_absolute_error(Y_test, y_pred)
mse = mean_squared_error(Y_test, y_pred)
r2 = r2_score(Y_test, y_pred)
acc=accuracy_score(Y_test,y_pred)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R2): {r2:.2f}")
print(f"Accuracy: {acc:.2f}")
# Out:
# Mean Absolute Error (MAE): 0.29
# Mean Squared Error (MSE): 0.29
# R-squared (R2): -0.17
# Accuracy: 0.71
